# %% [markdown]
# # Homework Assignment 1 - Git, Pandas, new Python packages, and Python classes

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Yash Kalani</p>
# ### <p style="text-align: right;"> &#9989; ykalani</p>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/9/98/F5_tornado_Elie_Manitoba_2007.jpg?utm_source=en.wikipedia.org&utm_campaign=imageinfo&utm_content=original" width=300px align="right" style="margin-left: 20px" alt="An image of a tornado, from Wikipedia">
#
# ## Goals for this homework assignment
# By the end of this assignment, you should be able to:
# * Use Git to create a repository, track changes to the files within the repository, and push those changes to a remote repository.
# * Debug some basic Python code that involves Pandas.
# * Read documentation and example code to use a new Python package
# * Modify and use a simple Python class
#
# Work through the following assignment, making sure to follow all of the directions and answer all of the questions.
#
# There are **75 points** possible on this assignment. Point values for each part are included in the section headers and question prompts.
#
# **This assignment is due at 11:59 pm on Friday, October 2.** It should be uploaded into the "Homework Assignments" submission folder for Homework #1 on D2L.  Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ### How this connects to the course learning goals
#
# Beyond the specific goals above, this homework builds toward these **course-level learning goals** (see the syllabus, or the Day 1 notebook, for the full CLG 1-7 list):
#
# - **CLG 1 - Design and write programs to solve problems:** you'll write pandas analysis code, mapping code with Folium, and a custom `VendingMachine` class.
# - **CLG 4 - Use modern development tools to build reusable programs:** you'll use Git (add/commit/push) throughout and write reusable class code.
# - **CLG 2 - Identify and use pre-existing tools and libraries:** you'll read the documentation for a new package (Folium), use pandas and matplotlib, and transparently document your use of AI tools (Part 5).
# - **CLG 5 - Manipulate, analyze, and visualize datasets:** you'll load, clean, aggregate, and visualize a real tornado dataset.
# - **CLG 7 - Explain your results in writing:** you'll describe data issues, justify your choices, and reflect on your process (including the Part 5 AI audit).

# %% [markdown]
# ## Part 0: Office Hours and Academic Integrity

# %% [markdown]
# ### CMSE 202 Office Hours/Help Rooms
#
# This is a reminder that CMSE 202 offers a help room that is available to students across all 3 sections. The help room is a great place to get assistance if you run into challenges while working through your homework assignment.
#
# **NOTE:** The days before a homework is due the help room tends to be very busy. To ensure you get adequate assistance, it is highly recommended that you start this homework early and seek help from office hours early.
#
# You can find the office hours calendar on the [course website](https://msu-cmse-courses.github.io/cmse202-Fall2026/).
#
# Office hour and help room locations are directly accessible from the calendar events. Some sessions are virtual, some are in-person, and some are hybrid. Check the event details before attending!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Academic Integrity Statement
#
# In the markdown cell below, paste your personal academic integrity statement (this can be a statement you have used in the past or a statement you craft now to highlight that your work reflects your own learning, understanding, and honest effort). By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.
#
# Reminder that, if you feel that a generative AI tool might help to support your learning on this assignment, you are encouraged to use the [HiTA learning assistant](https://msu-cmse-courses.github.io/cmse202-Fall2026/course_materials/CMSE202_HITA_Overview.html). If you use any generative AI for this assignment, including HiTA, you must cite the usage each time you use information from another source to give appropriate attribution to the origin of your work; See the [Course AI Policy](https://msu-cmse-courses.github.io/cmse202-Fall2026/course_materials/CMSE202_GenerativeAI_Policy.html) for additional details.
#
# **Notes**: As discussed at the beginning of the course, you are **allowed but NOT required** to use AI tools (e.g., ChatGPT, Copilot).  If you do choose to use them, you must do so in responsible, transparent, and ethical ways. For this particular assignment, if you end up using AI tools, you will be expected to document your usage in an "AI Audit Log" section near the end of this notebook. See the details in the "AI Audit Log" section below.

# %% [markdown]
# I certify that this submission represents my own authentic learning and effort, and that I fully understand and can explain all submitted code and analysis. I may utilize generative AI tools strictly as assistive learning aids for brainstorming, syntax reference, or debugging in alignment with the course policy. Whenever AI assistance is used, I will maintain academic integrity by transparently documenting and citing its role in the AI Audit Log.

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# ---
#
# ## Part 1: CLI and Git (10 points)
#
# ### Setting up a new folder in your Git repository and adding your HW1
# `git` is a very important professional tool and we want you to get plenty of practice using it. The following set of questions checks your understanding of using Git and the command line by having you add, commit, and push your homework file in your `cmse202-f26-turnin` repository. You will **share this repo with your course section instructor and TA** so that they can pull your completed assignments for grading. Additionally, please verify that your repository is setup as a `private` repository rather than a `public` repository.
#
# **Note**: Although you will be uploading your assignment to Github to practice Git commands, you are still expected to submit the assignment to D2L.

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 1.1 (1 points)**:
# 1. Navigate to your turnin repository on Github and add your section instructor and TA as a collaborator for the repository.
#
# This step is very important since we will need access to your repository to check the status of commits for homework assignments throughout the semester. To show you've done this, write the Github usernames of yourself and the instructor and TA below.
#
# **You should check the Teams channel, email, or D2L _for your section of the course_ to get this information.**

# %% [markdown]
# ```
# ### Write your Github username: ###
# ykalani
#
# ### Write your TA Github username: ###
# walke469
# martjor
# JoePetrecca
#
# ### Write your instructor Github username: ###
# termuhle
#
# ```

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 1.2 (1 point)**: Using the command line interface, on your local computer (JupyterHub or your machine) move inside the repository folder
#
# What command did you use to enter into the folder?

# %% [markdown]
# ```bash
# # Put the command to move into a new directory here.
# cd "folder of choice"
# ```

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 1.3 (1 point)**: Once inside the `cmse202-f26-turnin` repository, create a new folder called `hw-01`.
#
# What is the command to create the new folder ?

# %% [markdown]
# ```
# # Put the command to create the folder/directory here
# ```
# mkdir hw-01

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 1.4 (1 point)**: Move this notebook into that **new directory** in your repository then check the **_status_** of the repository
#
# <font color="red">**This is an important step**</font>: you'll want to make sure you **save and close** the notebook before you do this step and then re-open it once you've added it to your local repository directory. If you don't do this, you could end up working on the wrong version of the notebook! Once you've moved the notebook correctly, re-open it and continue working on it.

# %% [markdown]
# ```bash
# # Put the command you used to check the status of your repository here.
# ```
# mv HW01-GitPandasPackagesClasses-STUDENT.ipynb HW-01/
# git status

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 1.5 (1 point)**: Once you have checked the status of your repository, copy and paste the output of the status command in the cell below.

# %% [markdown]
# ``` bash
# # Paste it here
# ```
# S C:\Users\yash\world\code\cse\CMSE202\CMSE202-f26-turnin\hw-01> ls
#
#     Directory: C:\Users\yash\world\code\cse\CMSE202\CMSE202-f26-turnin\hw-01
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# -a---           9/24/2026  1:14 AM          43674 HW01-GitPandasPackagesClasses-STUDENT
#                                                   .ipynb

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 1.6 (1 point)**: What is the name of the current branch of the repository that you are in? (*Hint*: There should only be one branch at this time. We'll learn more about branches in git later in the semester.)

# %% [markdown]
# ```bash
# # Put your answer here
# ```
# main

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 1.7 (1 points)**:
# If you haven't already, add your name and GitHub username to the top of the notebook, then **add and commit ONLY** the notebook.  Be sure to use a descriptive commit message!

# %% [markdown]
# ``` bash
# # Put the command(s) to add and commit here
# git add .
# git commit -m "commit github username and instructor info"
# ```

# %% [markdown]
# What is the commit message you used ?

# %% [markdown]
# ``` bash
# # Copy your commit message here
# git commit -m "commit github username and instructor info"
#
# ```

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 1.8 (1 point):** Before moving on. Check that the notebook you are working on is the correct one. Run the following cell. **Are you in the new folder you just created?** If not close this notebook and open the one in the `hw-01` folder in your turnin repository. You'll likely need to copy of over the work you did on the above questions if you were working on the wrong notebook.  (The cell should be run to get credit for this question!)

# %%
# %pwd
# Out:
# 'c:\\Users\\yash\\world\\code\\cse\\CMSE202'

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 1.9 (1 points):** Assuming that you notebook is in the right place and committed to your repository, **push your changes to GitHub.**
#
# What command did you use to push your changes to GitHub?

# %% [markdown]
# ``` bash
# # Put the command you used to push your changes to GitHub here
# git push
# ```

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 1.10 (1 points):** To make sure that we can find your repository, what command should the instructor use to clone your repository from the command line?

# %% [markdown]
# ``` bash
# # Put the command to clone your repo here
# git clone https://github.com/ykalani/CMSE202-f26-turnin.git
# ```

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# ### Before moving on...
#
# **Important**: Make sure you've added your Professor and your TA as collaborators to your new "turnin" repository with "Read" access so that they can see your assignment. **You should check the Teams channel, email, or D2L _for your section of the course_ to get this information.**
#
# **Double-check the following**: Make sure that the version of this notebook that you are working on is the same one that you just added to your repository! If you are working on a different copy of the notebook, **none of your changes will be tracked**.
#
# If everything went as intended, **the file should now show up on your GitHub account** in the "`cmse202-f26-turnin`" repository inside the `hw-01` directory that you just created.  Periodically, **you'll be asked to commit your changes to the repository. By the end of the assignment you should have multiple commits that correspond to your completion of each section (as specified below)**. Of course, you can always commit your changes more often than that, if you wish.  It can be good to get into a habit of committing your changes any time you make a significant modification, or when you stop working on the project for a bit.

# %% [markdown]
# # Put your code here
#
# import pandas as pd
#
# df = pd.read_csv("1950-2025_actual_tornadoes.csv")
#
# # Display first 5 rows
# df.head()

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 2.1 (1 points):** Using the command line, download both the dataset and PDF description file to your local file system.  What is the command you used to accomplish this task?

# %% [markdown]
# # Put your code here
#
# import pandas as pd
#
# df = pd.read_csv("1950-2025_actual_tornadoes.csv")
#
# # Display first 5 rows
# df.head()

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 2.2 (2 points):** Now that you have the data, let's use Python to do some basic data analysis.  **Use Pandas to load in the data and display the first 5 rows.**
#
# *Note:* Use the default options for the read command for now. You will likely get a warning when you load in the data -- look at the next question!

# %%
# Put your code here

import pandas as pd

df = pd.read_csv("1950-2025_actual_tornadoes.csv")

df.head()
# Out:
# C:\Users\yash\AppData\Local\Temp\ipykernel_21216\87389527.py:5: DtypeWarning: Columns (0: om, 1: edat, 2: etime) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("1950-2025_actual_tornadoes.csv")
#     om    yr  mo  dy        date      time  tz  st  stf  stn  ...  ns  sn  sg  \
# 0  192  1950  10   1  1950-10-01  21:00:00   3  OK   40   23  ...   1   1   1
# 1  193  1950  10   9  1950-10-09  02:15:00   3  NC   37    9  ...   1   1   1
# 2  195  1950  11  20  1950-11-20  02:20:00   3  KY   21    1  ...   1   1   1
# 3  196  1950  11  20  1950-11-20  04:00:00   3  KY   21    2  ...   1   1   1
# 4  197  1950  11  20  1950-11-20  07:30:00   3  MS   28   14  ...   1   1   1
#
#     f1  f2  f3  f4  fc  edat  etime
# 0   25   0   0   0   0   NaN    NaN
# 1   47   0   0   0   0   NaN    NaN
# 2  177   0   0   0   0   NaN    NaN
# 3  209   0   0   0   0   NaN    NaN
# 4  101   0   0   0   0   NaN    NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 2.3 (3 points):** You likely received a warning when you loaded in the data in Question 2.2 that looked something like this:
#
# `DtypeWarning: Columns (0,29,30) have mixed types. Specify dtype option on import or set low_memory=False.`
#
# Look at the data and the documentation and see what would have caused the issue.  You may have to consult the internet to see what the error means!  If it is helpful, feel free to write some code to explore the data in the code cell below.  **Then, in the markdown cell below, describe in 2-3 sentences what the issue is and how you found the issue.**

# %% [markdown]
# >
# > Explain what caused the issue here - THIS IS WHAT WE WILL LOOK AT TO ASSESS YOUR ANSWER
# >
#
#  Columns om, edat, and etime contain mixed data types because earlier records use integers for om and missing NaN floats for ending dates/times, while records from late 2007 onwards use hyphenated string identifiers and date-time strings. I found this in column value types
#   and non-numeric values across rows using df.dtypes and unique().

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 2.4 (2 points):** In the markdown cell below, explain in a few sentences how you would resolve the issue so those three columns have a consistent format all the way through the dataframe.  We will not be using these three columns for this assignment, so it is not necessary to implement this code, but you should describe the process in your own words for this question.

# %% [markdown]
# >
# > Explain how you would fix columns 0, 29, and 30 here
# >
#
# To solve the mixed types I would specify the datatype with dtype={'om': str,
#   'edat': str, 'etime': str} inside pd.read_csv().  This would pre assign types to the variables.

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 2.5 (6 points):** Now let's start visualizing the data we have.  For this question, do the following:
# * Count the total number of tornadoes from each US state.  Store these values in an appropriate container such as a pandas dataframe. (2 points)
# * Sort the values in decreasing order, from most to least (1 point)
# * Make a barplot showing states in the x-axis and number of total tornadoes in the dataset on the y-axis (1 point)
# * Be sure to label your axes and title your graph! (2 point)
#
# There are many ways to do this.  For example, you could use masking and loops.  However, you may find it easier and cleaner to use the `.groupby()` function, which is built-in to pandas dataframes and can be combined with other functions (documentation found [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html) and user guide found [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html#splitting-an-object-into-groups)).  Just be sure to cite any resources you use to accomplish this problem!

# %%
# Put your code here
# Resource: pandas groupby docs (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html)

import matplotlib.pyplot as plt

# Count total tornadoes per state and store in dataframe
state_tornadoes = df.groupby("st").size()
state_tornadoes = state_tornadoes.reset_index(name="tornado_count")

# Sort descending from most to least
state_tornadoes = state_tornadoes.sort_values(by="tornado_count",ascending=False)

# Barplot
plt.figure(figsize=(14, 6))
plt.bar(state_tornadoes["st"], state_tornadoes["tornado_count"])
plt.xlabel("State")
plt.ylabel("Total Number of Tornadoes")
plt.title("Total Number of Tornadoes by US State (1950-2025)")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 2.6 (6 points):** Let's see how the annual number of tornadoes has changed over time -- both nationally and for Michigan specifically. Do the following:
# * Count the total number of tornadoes from each year across the entire US. Store these values in an appropriate container such as a pandas dataframe. (1 point)
# * Using **masking**, filter the dataset to Michigan (MI) only and count the total number of tornadoes from each year in MI. (2 points)
# * Make a plot (or plots) showing year on the x-axis and number of tornadoes on the y-axis, presenting **both** the US and Michigan trends. You may use two lines on the same axes or two subplots. Be sure to label your axes, give your plot(s) a title, and clearly distinguish the US and Michigan data (e.g., a legend, or subplot titles). (3 points)
#
# There are many ways to do this. **Tip:** the US has far more tornadoes per year than Michigan, so if you put both on the same axes the Michigan line will look nearly flat -- two subplots (or a second y-axis) can make the Michigan trend easier to see.

# %%
import matplotlib.pyplot as plt

us_annual = df.groupby("yr").size().reset_index(name="tornado_count")

mi_mask = df["st"] == "MI"
mi_df = df[mi_mask]
mi_annual = mi_df.groupby("yr").size().reset_index(name="tornado_count")

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

axes[0].plot(us_annual["yr"], us_annual["tornado_count"], color="steelblue", linewidth=2)
axes[0].set_xlabel("Year")
axes[0].set_ylabel("Number of Tornadoes")
axes[0].set_title("Annual Tornado Count: Entire US (1950-2025)")
axes[0].grid(True)

axes[1].plot(mi_annual["yr"], mi_annual["tornado_count"], color="darkorange", linewidth=2)
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Number of Tornadoes")
axes[1].set_title("Annual Tornado Count: Michigan (1950-2025)")
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 2.7 (1 point):** Pause to add and commit your changes to your Git repository!
#
# Take a moment to save your notebook, commit the changes to your Git repository using the commit message "Committing Part 2", no need to push the changes to GitHub, but you can if you want.

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# ___
#
# ## Part 3: New Packages  (16 points)

# %% [markdown]
# For this section, you will use `Folium` to plot the geographical data in the tornado data set.  You have already used `Folium` in a previous In-Class Assignment, but here you will explore some more capabilities that you may not have seen.  This will give you practice using online documentation and other resources to explore code that you are unfamiliar with.

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 3.1 (6 points):** To get a general sense of the data, we'll start by making a scatterplot of all the tornadoes that have been recorded in the state of Michigan.  To accomplish this, do the following:
# * Start with a folium `Map` centered on Michigan and zoomed so that the state covers most of the area of the map (2 points)
# * Add a folium `CircleMarker` at the appropriate coordinates where each tornado that started in the state of Michigan (MI) (which columns will you need to use here?)  (2 points)
# * Change the radius of the `CircleMarkers` so that the map is easy to read - an appropriate size might be 2 or 3 pixels (1 point)
# * Change the color to anything other than the default (1 point)

# %%
# Put your code here
import folium 

mi_map = folium.Map(location=[44.3148, -85.6024], zoom_start=7)

mi_df = df[df["st"] == "MI"]

for index, row in mi_df.iterrows():
    folium.CircleMarker(
        location=[row["slat"], row["slon"]],
        radius=2,
        color="red",
        fill=True,
        fill_color="red",
        fill_opacity=0.6,
    ).add_to(mi_map)

mi_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 3.2 (5 points):** With this data, we can also plot an approximate path that each tornado took.  For this part, do the following:
# * Start with the same folium `Map` you used in Question 3.1
# * Add a line for each tornado in MI that has the appropriate starting and ending coordinates - which folium command will you need to use here?  (2 points)
# * You will find that some of these paths don't make sense. Find a way to filter or manipulate the data appropriately so that the paths are reasonable.  Your decision for how you handle the data will involve some trade-offs; you will justify your approach in the next problem. (2 points)
# * Change the color to anything other than the default (1 point)
#
# If all goes well, you should end up with something that looks like the map shown on the tornado tracker at the [Midwestern Regional Climate Center at Purdue](https://mrcc.purdue.edu/gismaps/cntytorn).

# %%
# Put your code here

mi_map = folium.Map(location=[44.3148, -85.6024], zoom_start=7)

mi_df = df[df["st"] == "MI"]
mi_paths = mi_df[(mi_df["elat"]!= 0) & (mi_df["elon"] != 0)]

for index, row in mi_paths.iterrows():
    folium.PolyLine(
        locations=[[row["slat"], row["slon"]], [row["elat"], row["elon"]]],
        color="blue",
        weight=2,
        opacity=0.6,
    ).add_to(mi_map)

mi_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 3.3 (2 points):** In Question 3.2 you had to decide how to handle tornado records with missing or invalid end coordinates. In 2-3 sentences, describe the approach you chose and **justify it using what you observed in the data**. Also, **identify an alternative approach and what trade-offs would be made** with that approach.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here.*
#
# Filter out all records with lat and long of 0 because some of data uses 0.0 as placeholder values and arent accurate. Dropping these from the table stops us from drawing a bunch of lines at 0,0 which isn't in michigan.

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 3.4 (2 points):** By this point, you will have needed to use the documentation (the `SPC_severe_database_description` file) for the dataset substantially in order to choose appropriate columns for analysis.  You probably have a few complaints and/or ideas for how the documentation could be improved -- the instructional team sure did when we made this assignment!  List at least two ways the documentation could be improved.

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here.*
#
# 1.) say somewhere that 0.0 for lat and long are placeholder values and not the real locations of a tornado.
# 2.) list the expected data type of every column in order to dcument all changes nad switching from type to type.

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 3.5 (1 point):** Pause to add and commit your changes to your Git repository!
#
# Take a moment to save your notebook, commit the changes to your Git repository using the commit message "Committing Part 3", no need to push the changes to GitHub, but you can if you want.

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# ___
#
# ## Part 4: Python classes  (23 points)
#
# In this part of the assignment, you will practice defining classes with Python.  Here, you will create a class that will emulate the behavior of a vending machine.  Below is some skeleton code for us to start. This `VendingMachine` class has an `__init__` method and a `Restock` method defined, and a stub function for the `IsAvailable` method.  You will add functionality to the class in Q4.1.

# %%
## DO NOT MODIFY THIS CELL!! ##
class VendingMachine:
    def __init__(self,starting_treats):
        self.inventory = starting_treats
        self.stash = 0

    def Restock(self,new_list):
        for item in new_list:
            self.inventory.append(item)

    def IsAvailable(self, item):
        pass

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 4.1 (17 points):** In order to make the `VendingMachine` class functional, do the following:
# * (2 points) Modify the `IsAvailable` method.  This should:
#     * Take a string as input
#     * Check to see if that item is in the `inventory`.
#     * Return a boolean value.
# * (2 points) Give the machine a new attribute called `current_transaction`.
#     * This should be a numerical value and will be used to store how much money a customer has put in, in dollars.
#     * This should be set to zero when the Vending Machine is initialized.
# * (3 points) Add a method to the class called `InputCash`.  This should:
#     * take a numerical input
#     * add the input amount to the `current_transaction` attribute.
# * (3 points) Add a method called `Vend`.  This should:
#     * take a string as input
#     * remove the input string from the inventory attribute.
# * (7 points) Add another method called `MakeRequest`.  This should:
#     * Take a string as input
#     * Check to see if the `current_transaction` is greater than or equal to the price of the treat.  Let's be nostalgic and call this 1 dollar.
#     * Check to see if the request is an item in the `inventory`. You should use an existing method to accomplish this check!
#     * if the `current_transaction` value is not sufficient or the item is not available, do nothing
#     * if the `current_transaction` value is sufficient to purchase the treat, and the item is available:
#         * Remove one instance of that treat from the `inventory`. You should use an existing method to accomplish this!
#         * add 1 dollar to the `stash` attribute
#         * subtract 1 from the `current_transaction`

# %% [markdown]
# > **Progress checklist for Q4.1** — build and test your class one piece at a time. Double-click this cell and change each `[ ]` to `[x]` as you finish each item:
# >
# > - [x ] Added the `current_transaction` attribute, initialized to `0` in `__init__`
# > - [ x] `IsAvailable(item)` returns a boolean for whether the item is in `inventory`
# > - [x ] `InputCash(amount)` adds the amount to `current_transaction`
# > - [ x] `Vend(item)` removes the item from `inventory`
# > - [ x] `MakeRequest(item)` checks funds **and** availability, then vends, adds \$1 to `stash`, and subtracts \$1 from `current_transaction`
# > - [x ] The test cell below runs without errors

# %%
# Put your redefinition of the VendingMachine class here!
class VendingMachine:
    def __init__(self, starting_treats):
        self.inventory = starting_treats
        self.stash = 0
        self.current_transaction = 0

    def Restock(self, new_list):
        for item in new_list:
            self.inventory.append(item)

    def IsAvailable(self, item):
        return item in self.inventory

    def InputCash(self, amount):
        self.current_transaction += amount

    def Vend(self, item):
        self.inventory.remove(item)

    def MakeRequest(self, item):
        if self.current_transaction >= 1 and self.IsAvailable(item):
            self.Vend(item)
            self.stash += 1
            self.current_transaction -= 1

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# If all goes well, the test cell below should run *without errors*.  If there is an error, it means that your code is incorrect.  If there is no error, it is a good indicator that your code is written correctly.

# %%
# testing - do not change this cell!
vm1 = VendingMachine(['Twix','Snickers'])
vm1.Restock(['Twix','M&Ms','Chips Ahoy'])
assert(len(vm1.inventory)==5)
assert(vm1.IsAvailable('Twix')==True)
assert(vm1.IsAvailable('Chex Mix')==False)
vm1.InputCash(0.50)
vm1.MakeRequest('Twix')
assert(len(vm1.inventory)==5)
vm1.InputCash(1.75)
vm1.MakeRequest('Chex Mix')
assert(len(vm1.inventory)==5)
vm1.MakeRequest('Twix')
assert(len(vm1.inventory)==4)
vm1.MakeRequest('M&Ms')
assert(len(vm1.inventory)==3)
assert(vm1.stash==2)

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 4.2 (5 point):** This problem might seem rather contrived.  The last part of this problem asks you to envision a way we might use this class to do something useful.  In the Markdown cell below:
# * Write down one question we might be able to answer if we were to incorporate this class into an Agent Based Model. (1 point)
# * Specify another type of class that might be present in this ABM (1 point)
# * What attributes and methods would this other class have? (at least one attribute and one method) (2 pts)
# * Explain an interaction that might occur with these two classes (1 point)

# %% [markdown]
# <font size=6 color="#009600">&#9998;</font> *Put your answer here.*
#
# Question: How does campus student foot traffic and budget distribution affect how frequently vending machines run out of stock and need restocking?
#
# Other types: customer class or student class
#
# Attributes: wallet, snack_preference
# Methods: Buysnack(self, machine)
#
# Innteraction between classes:
# A customer approaches VendingMachine, checks machine.IsAvailable(self.snack_preference). If available and self.wallet >= 1, calls machine.
# InputCash(1), deducts $1 from self.wallet, and calls machine.
# MakeRequest(self.snack_preference), transferring money to machine stash
# and treat to customer.

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# &#9989; **Question 4.3 (1 point):** Pause to add and commit your changes to your Git repository!
#
# Take a moment to save your notebook, commit the changes to your Git repository using the commit message "Committing Part 4", no need to push the changes to GitHub, but you can if you want.

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# - - -
# ## Part 5: AI Audit Log (5 points)
#
# As mentioned above, you are allowed to use AI tools in the course and for this assignment, but you **must complete the table below to give an overview of your usage** (in additional to comment tags within your code cells that highlight AI-generated content or usage). If you used AI tools but did not document them here, that would be considered an integrity violation and does not align with your professional responsibility to be transparent about your process and the tools you use.
#
# If you did not use any AI tools, simply state "No AI tools used" in the table below and leave the rest of the columns blank.
#
# Remember, there is no inherent penalty for using AI tools, so transparency is valued here. The goal of this table is to encourage you to be mindful and intentional about how you use AI tools, and to reflect on their role in your workflow.
#
# **Add to the table below to document the role AI played in your work.** The first row is provided as an example.  If you *really* don't like Markdown tables, feel free to write a paragraph with the same information, just make sure it is easily readable.

# %% [markdown]
# | Assignment Section | AI Tool Used | Prompt(s) used | AI-generated Output | YOUR Changes/Why | Did you verify the output? How? |
# |--------------------|--------------|----------------|---------------------|------------------|---------------------------------|
# | Part 2.2, Reading in tornado data csv | ChatGPT | "How to read csv file with pandas" | Gave some example code, with how to specify different options | I kept the example code with the simplest pandas command as-is because it was sufficient for this question.  I did change the filename to match my own file | Yes, I looked at the first 5 rows and they matched with the csv file given |
# | ... | ... | ... | ... | ... | ... |
#
# *Or, if you prefer, write a paragraph here that addresses the same information as the table above.*

# %% [markdown]
# <!-- END QUESTION -->
# <!-- DO NOT MODIFY OR DELETE THIS CELL. Make sure your solution to the question above is in the cell(s) above this one. -->

# %% [markdown]
# ---

# %% [markdown]
# ### Congratulations, you're done!
#
# Submit this assignment by uploading it to the course **GradeScope** page, which you can find by using the dropdown menu on the right side of the navigation bar in D2L. Look for **"Homework 01 - Student Notebook Submission"** assignment and upload your Jupyter Notebook there -- once it uploads, double-check that you submitted the version with your completed solutions! You should also get a confirmation that a PDF version of your submission was successfully built. We will grade the PDF version. **Additional details for this submission process will be provided in class and share via Teams, email, and/or D2L.**

# %% [markdown]
# &#169; Copyright 2026,  Department of Computational Mathematics, Science and Engineering at Michigan State University
